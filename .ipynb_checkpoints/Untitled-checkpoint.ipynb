# %% [markdown]
# # Processing Embayment Constriction Mesurements
#
# Google earth was used to measure the morphological characteristics to determine the Constriction Ratio of large coastal features around the world. This analysis will use k-means clustering to assess whether or not ther is a suitable subset of large coastal features which can be morphologically classified as Large 'Embayments'. The geological composition (Bedrock/Regolith) of the confining morphological structures can then be used to separate Barrier Estuaries from Large Structural Embayments (LSEs).

# %% [markdown]
# ## Constriction Ratio
#
# The constriction ratio is the ratio between the width of the mouth of a coastal feature at its thinnest point (L<sub>m</sub>), to the width of the embayed body of water at its widest point (L<sub>b</sub>) [Figure 1](#fig1).
#
# <center>
#     <a name="fig1">
#         <img src="./test2.png" alt="drawing" width="300" />
#     </a>
# </center>
#
#
# The constriction ratio is then given by the equation:
#
# \begin{align}
# C = L_m/L_b
# \end{align}

# %% [markdown]
# ## Mesuring Embayments on Google Earth
#
# Identification of Coastal Features was peformed with an altitude set at 300km. Once a large coastal feature was identified, parameter measurement was conducted at a lower altitude to facilitate accurate measurment. Due to the real-world morphological complexity of Coastal Features, L<sub>m</sub> was measureed in multiple parts for Coastal Features with numerous significant mouths [Figure 2](#fig2).
#
# <a name="fig2">
#     <img src="./ComplexMorph.jpg" alt="ComplexMorph" width="1000"/>
# </a>

# %% [markdown]
# ## Cleaning Data
#
# Measurements were manually recorded in Excel and then saved to a .csv file for cleaning and statistical analysis with Python. Because Lat and Long point measurements were recorded ([see pin in figure 2](#fig2)), GeoPandas will be used to import and clean the dataset.

# %% [markdown]
# ### Importing data
# Data is imported using geopands and the first 4 entries are displayed to provide a better sense of the dataset.

# %%
import pandas as pd
import geopandas as gpd
from shapely.geometry import Point
import numpy as np
import dms2dd as dd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
plt.rcParams['figure.figsize'] = [15, 10]
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-85-4a2ff456fb2b> in <module>
#       5 import dms2dd as dd
#       6 import matplotlib.pyplot as plt
# ----> 7 import seaborn as sns
#       8 get_ipython().run_line_magic('matplotlib', 'inline')
#       9 plt.rcParams['figure.figsize'] = [15, 10]
#
# ModuleNotFoundError: No module named 'seaborn'

# %% [markdown]
# ```note
# Note: %matplotlib inline is used so that graphs are displayed in jupyter notebooks
# ```

# %%
df = pd.read_csv("./EmbaymentData_Prelim.csv", header=0)

# %%
df.head()
# Out:
#         Embayment Alt Name Papers Descriptor Type 1 Type 2 Size Margin Region  \
# 0  Akaroa Harbour      NaN      N    Harbour    NaN    NaN  NaN    NaN    NaN
# 1  Ambracian Gulf      NaN      Y       Gulf    NaN    NaN  NaN    NaN    NaN
# 2   Aotea Harbour      NaN      Y    Harbour    LSE  Tidal  NaN    NaN    NaN
# 3       Bafa Golu      NaN      Y       Lake    NaN    NaN  NaN    NaN    NaN
# 4   Boka Kotorska      NaN      Y        Bay    NaN    NaN  NaN    NaN    NaN
#
#   Country Ocean/Water Body Climate Zone (Koppen) Regional Process Dominance  \
# 0     NaN              NaN                   NaN                        NaN
# 1     NaN              NaN                   NaN                        NaN
# 2     NaN              NaN                   NaN                        NaN
# 3     NaN              NaN                   NaN                        NaN
# 4     NaN              NaN                   NaN                        NaN
#
#   Geology           P Lat          P Long     Lm      Lb            C
# 0     NaN             NaN             NaN    NaN     NaN      #DIV/0!
# 1     NaN             NaN             NaN    NaN     NaN      #DIV/0!
# 2     NaN   37°58'48.16"S  174°50'54.30"E  704.0  6804.0  0.103468548
# 3     NaN             NaN             NaN    NaN     NaN      #DIV/0!
# 4     NaN             NaN             NaN    NaN     NaN      #DIV/0!

# %%
df.columns
# Out:
# Index(['Embayment', 'Alt Name', 'Papers', 'Descriptor', 'Type 1', 'Type 2',
#        'Size', 'Margin', 'Region', 'Country', 'Ocean/Water Body',
#        'Climate Zone (Koppen)', 'Regional Process Dominance', 'Geology',
#        'P Lat', 'P Long', 'Lm', 'Lb', 'C'],
#       dtype='object')

# %% [markdown]
# ### Cleaning
# The relevant colums are:
# - Embayment
# - Type 1
# - Margin
# - Ocean/Water Body
# - Climate Zone (Koppen)
# - Regional Process Dominance
# - P Lat
# - P Long
# - Lm
# - Lb
# - C
#
# These will be subsetted from the dataset.

# %%
df2 = df[['Embayment', 
             'Type 1',
             'Margin',
             'Ocean/Water Body',
             'Climate Zone (Koppen)',
             'Regional Process Dominance',
             'P Lat',
             'P Long',
             'Lm',
             'Lb',
             'C']]

# %%
df2.head()
# Out:
#         Embayment Type 1 Margin Ocean/Water Body Climate Zone (Koppen)  \
# 0  Akaroa Harbour    NaN    NaN              NaN                   NaN
# 1  Ambracian Gulf    NaN    NaN              NaN                   NaN
# 2   Aotea Harbour    LSE    NaN              NaN                   NaN
# 3       Bafa Golu    NaN    NaN              NaN                   NaN
# 4   Boka Kotorska    NaN    NaN              NaN                   NaN
#
#   Regional Process Dominance           P Lat          P Long     Lm      Lb  \
# 0                        NaN             NaN             NaN    NaN     NaN
# 1                        NaN             NaN             NaN    NaN     NaN
# 2                        NaN   37°58'48.16"S  174°50'54.30"E  704.0  6804.0
# 3                        NaN             NaN             NaN    NaN     NaN
# 4                        NaN             NaN             NaN    NaN     NaN
#
#              C
# 0      #DIV/0!
# 1      #DIV/0!
# 2  0.103468548
# 3      #DIV/0!
# 4      #DIV/0!

# %%
df2.describe()
# Out:
#                  Lm            Lb
# count     70.000000     70.000000
# mean   17004.885714  25609.171429
# std    20981.358752  23061.817085
# min      290.000000   2605.000000
# 25%     1577.750000   8614.750000
# 50%     5714.500000  17122.000000
# 75%    28088.500000  37382.000000
# max    80096.000000  97958.000000

# %% [markdown]
# ### Removing NA and #DIV/0!
#
# Many of these cells do not have appropriate values in them. Because a fomula was applied across the C column in Excel, many NA values are actually read as #DIV/0!.
#
# These will need to be removed alongside entries with little to no data entered. Since the main focus of this portion of the study is the C ratio, rows without Lm or Lb values will be removed and #DIV/0! values will be removed alongside them.
#
# First we will replace empty values with numpys NaN using regex.

# %%
df2 = df2.replace('', np.nan)

# %% [markdown]
# #### Removing NaN
#
# Pandas DataFrame.dropna() with the option subset=[] is used to drop rows where the L<sub>m</sub> and L<sub>b</sub> parameters are not measured.

# %%
dfclean = df2.dropna(subset=['Lm', 'Lb', 'P Lat', 'P Long'])

# %%
dfclean
# Out:
#                   Embayment           Type 1   Margin Ocean/Water Body  \
# 2             Aotea Harbour              LSE      NaN              NaN
# 5                Botany Bay              LSE      NaN              NaN
# 13          Kaipara Harbour              LSE   Active              NaN
# 15           Kawhia Harbour              LSE   Active              NaN
# 22          Manukau Harbour              LSE   Active              NaN
# 28         Port Phillip Bay              LSE  Passive       Tasman Sea
# 30           Raglan Harbour              LSE   Active              NaN
# 31        San Francisco Bay              LSE   Active              NaN
# 36       Wellington Harbour              LSE   Active              NaN
# 37         Western Port Bay              LSE  Passive       Tasman Sea
# 38        Whangaroa Harbour              NaN      NaN              NaN
# 39          Whanganui Inlet              LSE   Active              NaN
# 41             Corner Inlet              LSE  Passive       Tasman Sea
# 42             Disaster Bay              OPN  Passive              NaN
# 43            East Boyd Bay              OPN  Passive              NaN
# 45             Batemans Bay              TDL  Passive              NaN
# 46               Jervis Bay              LSE  Passive              NaN
# 47          Lake Illawarra          BAR EST.  Passive              NaN
# 48           Sydney Harbour              Ria  Passive              NaN
# 49               Broken Bay              Ria  Passive              NaN
# 50           Lake Macquarie              Ria  Passive              NaN
# 51           Shoalwater Bay       Macrotidal  Passive              NaN
# 52              Broad Sound       Macrotidal  Passive              NaN
# 53            Cleveland Bay             Open  Passive              NaN
# 54              Halifax Bay             Open  Passive              NaN
# 55   Princess Charlotte Bay             Open  Passive              NaN
# 56             Blue Mud Bay             Open  Passive              NaN
# 57               Arnhem Bay             Open  Passive              NaN
# 58                Shark Bay              NaN  Passive              NaN
# 59             Exmouth Gulf              NaN  Passive              NaN
# ..                      ...              ...      ...              ...
# 70                Takou Bay             Open  Active               NaN
# 71                Hawke Bay             Open  Active               NaN
# 72           Mangonui Inlet              Ria  Active               NaN
# 73           Kerikeri Inlet              Ria  Active               NaN
# 74            Waikare Inlet      Tidal Inlet  Active               NaN
# 75        Waitamata Harbour              LSE  Active               NaN
# 76          Frith of Thames              LSE  Active               NaN
# 77         Tauranga Harbour              LSE  Active               NaN
# 78              Pegasus Bay             Open  Active               NaN
# 79              Golden Bay               NaN  Active               NaN
# 80               Tasman Bay              NaN  Active               NaN
# 81           Paterson Inlet              LSE   Active              NaN
# 82               Awarua Bay      Tidal Inlet   Active              NaN
# 83             Tewaenae Bay             Open  Active               NaN
# 85              Yakutat Bay            Fjord  Active               NaN
# 86            Grays Harbour  Barrier Estuary  Active               NaN
# 87              Willapa Bay  Barrier Estuary  Active               NaN
# 88   Columbia River Estuary  Barrier Estuary  Active               NaN
# 89             Monterey Bay             Open  Active               NaN
# 90               Estero Bay             Open  Active               NaN
# 91         Santa Monica Bay             Open  Active               NaN
# 92            San Pedro Bay             Open  Active               NaN
# 93            San Diego Bay  Barrier Estuary  Active               NaN
# 94           All Saints Bay             Open  Active               NaN
# 95      Ojo de Libre Lagoon  Barrier Estuary  Active               NaN
# 96     Saint Ignacio Lagoon  Barrier Estuary  Active               NaN
# 97           Conception Bay              LSE  Active               NaN
# 98             Banderas Bay             Open  Active               NaN
# 99          Gulf of Fonseca             Open  Active               NaN
# 100          Gulf of Nicoya       Macrotidal  Active               NaN
#
#     Climate Zone (Koppen) Regional Process Dominance           P Lat  \
# 2                     NaN                        NaN   37°58'48.16"S
# 5                     Cfb                        NaN   33°59'27.52"S
# 13                    Cfb                   Wave (?)   36°23'14.53"S
# 15                    Cfb                   Wave (?)   38° 5'45.47"S
# 22                    Cfb                   Wave (?)   37° 1'20.72"S
# 28                    Cfb                        NaN   38° 5'45.53"S
# 30                    Cfb                        NaN   37°47'37.70"S
# 98   105°24'54.79"W  29266.0  27785.0  1.053302141
# 99    87°38'59.19"W  32011.0  71729.0  0.446276959
# 100   84°49'23.76"W  30602.0  18906.0  1.618639585
#
# [69 rows x 11 columns]

# %% [markdown]
# ### Data Types
# Many of the datatypes in this table are now wrong

# %%
dfclean.dtypes
# Out:
# Embayment                      object
# Type 1                         object
# Margin                         object
# Ocean/Water Body               object
# Climate Zone (Koppen)          object
# Regional Process Dominance     object
# P Lat                          object
# P Long                         object
# Lm                            float64
# Lb                            float64
# C                              object
# dtype: object

# %% [markdown]
# ## Data Analysis
#
# In this section, a k-means cluster analysis is performed to group Coastal Features by C ratio. This should help to determine whether or not there is a LSE subclass. But first we will plot the coastal features as a scatter plot to see their distribution.

# %%
dfclean.plot.scatter(x='Lm', y='Lb')

# %%
plt.scatter(x=dfclean['Lm'], y=dfclean['Lb'])
x=np.linspace(0, max(dfclean['Lb']), 100)
y=x
y2=3*x
plt.plot(x, y, 'r--')
plt.plot(x, y2, 'g--')
plt.axis([0, max(dfclean['Lm']), 0, max(dfclean['Lb'])])
plt.xlabel('Minimum Mouth Width (Lm)')
plt.ylabel('Maximum Body Width (Lb)')
plt.show()

# %% [markdown]
# In this instance, the further away a point is from the red line, the more embayed a coastal feature is. The green line represents:
# \begin{align}
# \frac{L_m}{3L_b}
# \end{align}
# Which can also be stated as as $C=0.3$, an consequently anything above the ***green*** line is $< C=0.3$ and considered 'Embayed'. Additionally, any points on or below ***red*** line are considered open and the further away they are from the ***red*** line they are the more hypersynchronous they are.

# %% [markdown]
# ### Global Distribution
#
# The distribution of Coastal Features reviewed for this literature review can be displayed using geopandas. However geopandas works best if the latitude and longitude are in ***Decimal Degrees*** rather than their current format ***Degrees Minutes Seconds***. To solve this I have written a simple function which converts from ***DMS*** to ***DD***. This function can be applied to both latitude and longitude and then those values will be stored in a list alongside the ***Point*** geometry type for later plotting.
#
# First conversion from ***DMS*** to ***DD***. Notethe use of custom scrip dd.convert

# %%
dfclean.loc[:,'Lat'] = dfclean['P Lat'].apply(dd.convert)
dfclean.loc[:,'Long'] = dfclean['P Long'].apply(dd.convert)

# %%
dfclean.head()
# Out:
#           Embayment Type 1  Margin Ocean/Water Body Climate Zone (Koppen)  \
# 2     Aotea Harbour    LSE     NaN              NaN                   NaN
# 5        Botany Bay    LSE     NaN              NaN                   Cfb
# 13  Kaipara Harbour    LSE  Active              NaN                   Cfb
# 15   Kawhia Harbour    LSE  Active              NaN                   Cfb
# 22  Manukau Harbour    LSE  Active              NaN                   Cfb
#
#    Regional Process Dominance           P Lat          P Long      Lm  \
# 2                         NaN   37°58'48.16"S  174°50'54.30"E   704.0
# 5                         NaN   33°59'27.52"S  151°12'12.48"E  1115.0
# 13                   Wave (?)   36°23'14.53"S  174°12'27.57"E  7196.0
# 15                   Wave (?)   38° 5'45.47"S  174°49'56.60"E   986.0
# 22                   Wave (?)   37° 1'20.72"S  174°41'19.42"E  1923.0
#
#          Lb            C        Lat        Long
# 2    6804.0  0.103468548 -37.980044  174.848417
# 5    7948.0        #REF! -33.990978  151.203467
# 13  58071.0  0.123917274 -36.387369  174.207658
# 15  12339.0  0.079909231 -38.095964  174.832389
# 22  23754.0  0.080954787 -37.022422  174.688728

# %% [markdown]
# Now we convert the DD lat long into Points from the Shapely.geometry module by:

# %%
geometry = [Point(x,y) for x,y in zip(dfclean['Long'], dfclean['Lat'])]

gfd=gpd.GeoDataFrame(dfclean, geometry=geometry)

# %% [markdown]
# Importing a world map to plot against:

# %%
world_url = 'https://d2ad6b4ur7yvpq.cloudfront.net/naturalearth-3.3.0/ne_50m_admin_0_countries.geojson'
world = gpd.read_file(world_url)

# %%
base = world.plot(color='white', edgecolor='black')

gfd.plot(ax=base, marker='o', color='red', markersize=10)

# %% [markdown]
# ## K-Means clustering
#
# Clustering analysis of the embayment measurements should yield morphological archetypes for large coastal features. This analysis will be conducted here using the kmeans module from sklearn.cluster package.
#
# ### Using K-Means
# First we create a subset of dfclean (because it is a Pandas DataFrame not a Geopandas GeoDataFrame) and store it in the variable ***X***. Then we set up the model options and store them in the variable ***kmeans***. Lastly, we create the model by applying the _KMeans.fit(X)_ method and store it in ***kluster***. ***kluster*** now contains the model and centroids for the cluster analysis that we just performed.

# %%
from sklearn.cluster import KMeans

X = dfclean.loc[:,['Type 1','Lm', "Lb"]]
kmeans = KMeans(n_clusters=5, max_iter=1000)
kluster = kmeans.fit(X.loc[:,["Lm","Lb"]])

# %% [markdown]
# ### Cluster Centers
#
# The computed cluster centers (we specified 3) are stored in the attribute ***cluster_centers_***. Calling this attribute shows that the centroid coordinates are stored in a numpy array (may be useful to know).

# %%
kluster.cluster_centers_
# Out:
# array([[ 3100.60526316, 11275.15789474],
#        [26501.92307692, 22272.69230769],
#        [68115.33333333, 91153.        ],
#        [10922.        , 58536.33333333],
#        [50413.77777778, 49348.66666667]])

# %% [markdown]
# ### Determining Cluster Category
#
# Determination of each points 'Cluster' is done by applying the ***predict()*** method for each point in the DataFrame ***X***. Here we store those values in the column ***'Cluster'***.

# %%
X['Cluster'] = kluster.predict(X.loc[:,["Lm","Lb"]])

# %%
X
# Out:
#                   Type 1       Lm       Lb Cluster
# 2                    LSE    704.0   6804.0       0
# 5                    LSE   1115.0   7948.0       0
# 13                   LSE   7196.0  58071.0       3
# 15                   LSE    986.0  12339.0       0
# 22                   LSE   1923.0  23754.0       0
# 28                   LSE   3472.0  51901.0       3
# 30                   LSE    612.0   6946.0       0
# 31                   LSE   1688.0  83811.0       3
# 36                   LSE   2693.0  11533.0       0
# 37                   LSE   7690.0  23135.0       0
# 38                   NaN    290.0   3794.0       0
# 39                   LSE   1129.0  12255.0       0
# 41                   LSE   2122.0  25119.0       0
# 42                   OPN   7072.0   6226.0       0
# 43                   OPN   5092.0   6679.0       0
# 45                   TDL   6166.0   6325.0       0
# 46                   LSE   3551.0  16171.0       0
# 47              BAR EST.    414.0   8609.0       0
# 48                   Ria   1472.0   9023.0       0
# 49                   Ria   3760.0  14516.0       0
# 50                   Ria    444.0  14146.0       0
# 51            Macrotidal  27876.0  14032.0       1
# 52            Macrotidal  28104.0  10771.0       1
# 53                  Open  24983.0  21382.0       1
# 54                  Open  75243.0  52692.0       4
# 55                  Open  50283.0  48317.0       4
# 56                  Open  45938.0  89765.0       2
# 57                  Open  14181.0  45471.0       3
# 58                   NaN  39962.0  47989.0       4
# 59                   NaN  47413.0  38438.0       4
# ...                  ...      ...      ...     ...
# 72                   Ria   1019.0   3493.0       0
# 73                   Ria   1261.0   2605.0       0
# 74           Tidal Inlet    482.0   6437.0       0
# 75                   LSE   1775.0   8093.0       0
# 76                   LSE  16516.0  21660.0       1
# 77                   LSE   1257.0  14628.0       0
# 78                  Open  65163.0  57563.0       4
# 79                   NaN  34481.0  34214.0       1
# 80                   NaN  35691.0  27603.0       1
# 81                   LSE   1529.0   6222.0       0
# 82           Tidal Inlet    666.0   5575.0       0
# 83                  Open  26762.0  30936.0       1
# 85                 Fjord  28042.0  26862.0       1
# 86       Barrier Estuary   3380.0  20147.0       0
# 87       Barrier Estuary   6984.0  40235.0       3
# 88       Barrier Estuary   5263.0  12263.0       0
# 89                  Open  35177.0  42076.0       4
# 90                  Open  18248.0  15595.0       1
# 91                  Open  43216.0  43232.0       4
# 92                  Open  25742.0  18590.0       1
# 93       Barrier Estuary   1422.0  17172.0       0
# 94                  Open  14080.0  15919.0       0
# 95       Barrier Estuary   3694.0  23733.0       0
# 96       Barrier Estuary   3848.0   6794.0       0
# 97                   LSE   3860.0   9676.0       0
# 98                  Open  29266.0  27785.0       1
# 99                  Open  32011.0  71729.0       3
# 100           Macrotidal  30602.0  18906.0       1
# Type 1               NaN      NaN      NaN     nan
# Cluster              nan      NaN      NaN     nan
#
# [71 rows x 4 columns]

# %% [markdown]
# ### Graphing
#
# Now we can graphically display the cluster grouping using matplotlib.

# %%
colours={0:'r',1:'b', 2:'g', 3:'black', 4: 'y', 5: 'purple', 6:'orange'}

plt.scatter(x=X['Lm'], y=X['Lb'], c=X['Cluster'].apply(lambda x: colours[x]))
x=np.linspace(0, max(X['Lb']), 100)
y=x
y2=3*x
plt.plot(x, y, 'r--')
plt.plot(x, y2, 'g--')
plt.axis([0, max(dfclean['Lm']), 0, max(dfclean['Lb'])])
plt.xlabel('Minimum Mouth Width (Lm)')
plt.ylabel('Maximum Body Width (Lb)')
plt.show()

# %%
X.loc["Type 1"] = X["Type 1"].str.strip()
X.loc["Cluster"] = X["Cluster"].apply(lambda x: str(x))
histdf = X.groupby(["Type 1", "Cluster"])
histdf.count()
# Out:
#                          Lm  Lb
# Type 1          Cluster
# BAR EST.        0.0       1   1
# Barrier Estuary 0.0       5   5
#                 3.0       1   1
# Fjord           1.0       1   1
# LSE             0.0      15  15
#                 1.0       1   1
#                 3.0       3   3
# Macrotidal      1.0       4   4
#                 2.0       1   1
#                 4.0       2   2
# OPN             0.0       2   2
# Open            0.0       4   4
#                 1.0       5   5
#                 2.0       2   2
#                 3.0       2   2
#                 4.0       5   5
# Ria             0.0       5   5
# TDL             0.0       1   1
# Tidal Inlet     0.0       4   4
# nan             nan       0   0

# %% [markdown]
# ### Subsetting Data
#
# As you can see, a large potion of the classified data is a part of cluster 0. This could be due to the distribution of other clusters on the euclidean plane. The next step is to remove the sparse points and re-calculate the clustering model. This should be able to provide more appropriate clustering for the dataset. It may be worthwhile reclassifying the sparse points as 'Massive' coastal features. These are not really the concern of this study
