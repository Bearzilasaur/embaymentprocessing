# %% [markdown]
# # Processing Embayment Constriction Mesurements
#
# Google earth was used to measure the morphological characteristics to determine the Constriction Ratio of large coastal features around the world. This analysis will use k-means clustering to assess whether or not ther is a suitable subset of large coastal features which can be morphologically classified as Large 'Embayments'. The geological composition (Bedrock/Regolith) of the confining morphological structures can then be used to separate Barrier Estuaries from Large Structural Embayments (LSEs).

# %% [markdown]
# ## Constriction Ratio
#
# The constriction ratio is the ratio between the width of the mouth of a coastal feature at its thinnest point (L<sub>m</sub>), to the width of the embayed body of water at its widest point (L<sub>b</sub>) [Figure 1](#fig1).
#
# <center>
#     <a name="fig1">
#         <img src="./test2.png" alt="drawing" width="300" />
#     </a>
# </center>
#
#
# The constriction ratio is then given by the equation:
#
# \begin{align}
# C = L_m/L_b
# \end{align}

# %% [markdown]
# ## Mesuring Embayments on Google Earth
#
# Identification of Coastal Features was peformed with an altitude set at 300km. Once a large coastal feature was identified, parameter measurement was conducted at a lower altitude to facilitate accurate measurment. Due to the real-world morphological complexity of Coastal Features, L<sub>m</sub> was measureed in multiple parts for Coastal Features with numerous significant mouths [Figure 2](#fig2).
#
# <a name="fig2">
#     <img src="./ComplexMorph.jpg" alt="ComplexMorph" width="1000"/>
# </a>

# %% [markdown]
# ## Cleaning Data
#
# Measurements were manually recorded in Excel and then saved to a .csv file for cleaning and statistical analysis with Python. Because Lat and Long point measurements were recorded ([see pin in figure 2](#fig2)), GeoPandas will be used to import and clean the dataset.

# %% [markdown]
# ### Importing data
# Data is imported using geopands and the first 4 entries are displayed to provide a better sense of the dataset.

# %%
import pandas as pd
import geopandas as gpd
from shapely.geometry import Point
import numpy as np
import dms2dd as dd

#import seaborn as sns
import matplotlib.pyplot as plt
#from plotnine import *
# %matplotlib inline
plt.rcParams['figure.figsize'] = [15, 10]

# %% [markdown]
# ```note
# Note: %matplotlib inline is used so that graphs are displayed in jupyter notebooks
# ```

# %%
df = pd.read_csv("./EmbaymentData_Basic1.csv", header=0, encoding='utf-8')

# %%
df.head()
# Out:
#              Embayment Descriptor           Type 1        Type 2  \
# 0      Tamiahua Lagoon     Lagoon  Barrier Estuary        Lagoon
# 1  Lagoon of Caratasca     Lagoon  Barrier Estuary           NaN
# 2    San Francisco Bay        Bay              LSE           Ria
# 3       Lake Macquarie       Lake              Ria     Bar Est.
# 4      Lake Illawarra        Lake  Barrier Estuary  COAST. PLAIN
#
#             P Lat          P Long    Lm     Lb            C
# 0   21°34'46.90"N   97°32'50.12"W   135  20346  0.006635211
# 1   15°21'21.71"N    83°50'7.78"W   562  50805  0.011061903
# 2   37°50'41.11"N  122°22'32.42"W  1688  83811  0.020140554
# 3   33° 5'36.58"S  151°36'14.48"E   444  14146  0.031386965
# 4   34°31'21.44"S  150°50'18.66"E   414   8609  0.048089209

# %%
df.columns
# Out:
# Index(['Embayment', 'Descriptor', 'Type 1', 'Type 2', 'P Lat', 'P Long', 'Lm',
#        'Lb', 'C'],
#       dtype='object')

# %% [markdown]
# ### Cleaning
# The relevant colums are:
# - Embayment
# - Type 1
# - Margin
# - Ocean/Water Body
# - Climate Zone (Koppen)
# - Regional Process Dominance
# - P Lat
# - P Long
# - Lm
# - Lb
# - C
#
# These will be subsetted from the dataset.
#
# # NOTE
#
# This is now not important as the basic information is stored as is in the file. No need to remove columns.

# %%
df2 = df
#df2 = df[['Embayment', 
#             'Type 1',
#             'Margin',
#             'Ocean/Water Body',
#             'Climate Zone (Koppen)',
#             'Regional Process Dominance',
#             'P Lat',
#             'P Long',
#             'Lm',
#             'Lb',
#             'C']]

# %%
df2.head()
# Out:
#              Embayment Descriptor           Type 1        Type 2  \
# 0      Tamiahua Lagoon     Lagoon  Barrier Estuary        Lagoon
# 1  Lagoon of Caratasca     Lagoon  Barrier Estuary           NaN
# 2    San Francisco Bay        Bay              LSE           Ria
# 3       Lake Macquarie       Lake              Ria     Bar Est.
# 4      Lake Illawarra        Lake  Barrier Estuary  COAST. PLAIN
#
#             P Lat          P Long    Lm     Lb            C
# 0   21°34'46.90"N   97°32'50.12"W   135  20346  0.006635211
# 1   15°21'21.71"N    83°50'7.78"W   562  50805  0.011061903
# 2   37°50'41.11"N  122°22'32.42"W  1688  83811  0.020140554
# 3   33° 5'36.58"S  151°36'14.48"E   444  14146  0.031386965
# 4   34°31'21.44"S  150°50'18.66"E   414   8609  0.048089209

# %%
df2.describe()
# Out:
#                  Lm             Lb
# count    109.000000     109.000000
# mean   15900.614679   28514.917431
# std    18513.732206   22815.635475
# min      135.000000    2605.000000
# 25%     2122.000000   12263.000000
# 50%     8371.000000   21660.000000
# 75%    23507.000000   40235.000000
# max    80096.000000  120752.000000

# %% [markdown]
# ### Removing NA and #DIV/0!
#
# Many of these cells do not have appropriate values in them. Because a fomula was applied across the C column in Excel, many NA values are actually read as #DIV/0!.
#
# These will need to be removed alongside entries with little to no data entered. Since the main focus of this portion of the study is the C ratio, rows without Lm or Lb values will be removed and #DIV/0! values will be removed alongside them.
#
# First we will replace empty values with numpys NaN using regex.

# %%
df2 = df2.replace('', np.nan)

# %% [markdown]
# #### Removing NaN
#
# Pandas DataFrame.dropna() with the option subset=[] is used to drop rows where the L<sub>m</sub> and L<sub>b</sub> parameters are not measured.

# %%
dfclean = df.dropna(subset=['Lm', 'Lb', 'P Lat', 'P Long'])

# %%
dfclean
# Out:
#                Embayment Descriptor           Type 1        Type 2  \
# 0        Tamiahua Lagoon     Lagoon  Barrier Estuary        Lagoon
# 1    Lagoon of Caratasca     Lagoon  Barrier Estuary           NaN
# 2      San Francisco Bay        Bay              LSE           Ria
# 3         Lake Macquarie       Lake              Ria     Bar Est.
# 4        Lake Illawarra        Lake  Barrier Estuary  COAST. PLAIN
# ..                   ...        ...              ...           ...
# 104       Gulf of Nicoya       Gulf       Macrotidal           NaN
# 105       Shoalwater Bay        Bay       Macrotidal       Estuary
# 106        Bay of Marajó        Bay              NaN           NaN
# 107          Broad Sound      Sound       Macrotidal       Estuary
# 108           Botany Bay        Bay              LSE           Ria
#
#               P Lat          P Long     Lm     Lb            C
# 0     21°34'46.90"N   97°32'50.12"W    135  20346  0.006635211
# 1     15°21'21.71"N    83°50'7.78"W    562  50805  0.011061903
# 2     37°50'41.11"N  122°22'32.42"W   1688  83811  0.020140554
# 3     33° 5'36.58"S  151°36'14.48"E    444  14146  0.031386965
# 4     34°31'21.44"S  150°50'18.66"E    414   8609  0.048089209
# ..              ...             ...    ...    ...          ...
# 104    9°53'15.63"N   84°49'23.76"W  30602  18906  1.618639585
# 105   22°26'19.99"S  150°26'50.31"E  27876  14032  1.986602052
# 106    0°39'57.20"S   48°19'12.53"W  59760  29500  2.025762712
# 107   22°21'52.17"S  149°51'40.40"E  28104  10771  2.609228484
# 108   33°59'27.52"S  151°12'12.48"E   1115   7948        #REF!
#
# [106 rows x 9 columns]

# %% [markdown]
# ### Data Types
# Many of the datatypes in this table are now wrong

# %%
dfclean.dtypes
# Out:
# Embayment     object
# Descriptor    object
# Type 1        object
# Type 2        object
# P Lat         object
# P Long        object
# Lm             int64
# Lb             int64
# C             object
# dtype: object

# %% [markdown]
# ## Data Analysis
#
# In this section, a k-means cluster analysis is performed to group Coastal Features by C ratio. This should help to determine whether or not there is a LSE subclass. But first we will plot the coastal features as a scatter plot to see their distribution.

# %%
dfclean.plot.scatter(x='Lm', y='Lb')

# %%
plt.scatter(x=dfclean['Lm'], y=dfclean['Lb'])
x=np.linspace(0, max(dfclean['Lb']), 100)
y=x
y2=3*x
plt.plot(x, y, 'r--')
plt.plot(x, y2, 'g--')
plt.axis([0, max(dfclean['Lm']), 0, max(dfclean['Lb'])])
plt.xlabel('Minimum Mouth Width (Lm)')
plt.ylabel('Maximum Body Width (Lb)')

plt.savefig("./images/ScatterPlot.svg")
plt.savefig("./images/ScatterPlot.png")

plt.show()

# %% [markdown]
# In this instance, the further away a point is from the red line, the more embayed a coastal feature is. The green line represents:
# \begin{align}
# \frac{L_m}{3L_b}
# \end{align}
# Which can also be stated as as $C=0.3$, an consequently anything above the ***green*** line is $< C=0.3$ and considered 'Embayed'. Additionally, any points on or below ***red*** line are considered open and the further away they are from the ***red*** line they are the more hypersynchronous they are.

# %% [markdown]
# ### Global Distribution
#
# The distribution of Coastal Features reviewed for this literature review can be displayed using geopandas. However geopandas works best if the latitude and longitude are in ***Decimal Degrees*** rather than their current format ***Degrees Minutes Seconds***. To solve this I have written a simple function which converts from ***DMS*** to ***DD***. This function can be applied to both latitude and longitude and then those values will be stored in a list alongside the ***Point*** geometry type for later plotting.
#
# First conversion from ***DMS*** to ***DD***. Notethe use of custom scrip dd.convert

# %%
dfclean['Lat'] = dfclean.loc[:,'P Lat'].apply(dd.convert)   # Applying the custom function from the dms2dd package
dfclean['Long'] = dfclean.loc[:,'P Long'].apply(dd.convert)
# Out:
# //anaconda3/envs/embayments/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# //anaconda3/envs/embayments/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
dfclean.head()
# Out:
#              Embayment Descriptor           Type 1        Type 2  \
# 0      Tamiahua Lagoon     Lagoon  Barrier Estuary        Lagoon
# 1  Lagoon of Caratasca     Lagoon  Barrier Estuary           NaN
# 2    San Francisco Bay        Bay              LSE           Ria
# 3       Lake Macquarie       Lake              Ria     Bar Est.
# 4      Lake Illawarra        Lake  Barrier Estuary  COAST. PLAIN
#
#             P Lat          P Long    Lm     Lb            C        Lat  \
# 0   21°34'46.90"N   97°32'50.12"W   135  20346  0.006635211  21.579694
# 1   15°21'21.71"N    83°50'7.78"W   562  50805  0.011061903  15.356031
# 2   37°50'41.11"N  122°22'32.42"W  1688  83811  0.020140554  37.844753
# 3   33° 5'36.58"S  151°36'14.48"E   444  14146  0.031386965 -33.093494
# 4   34°31'21.44"S  150°50'18.66"E   414   8609  0.048089209 -34.522622
#
#          Long
# 0  -97.547256
# 1  -83.835494
# 2 -122.375672
# 3  151.604022
# 4  150.838517

# %% [markdown]
# Now we convert the DD lat long into Points from the Shapely.geometry module by:

# %%
geometry = [Point(x,y) for x,y in zip(dfclean['Long'], dfclean['Lat'])]

gfd=gpd.GeoDataFrame(dfclean, geometry=geometry)

# %% [markdown]
# Importing a world map to plot against:

# %%
world_url = 'https://d2ad6b4ur7yvpq.cloudfront.net/naturalearth-3.3.0/ne_50m_admin_0_countries.geojson'
world = gpd.read_file(world_url)

# %%
world.head()
# Out:
#    scalerank  labelrank      sovereignt sov_a3  adm0_dif  level  \
# 0          3          5     Netherlands    NL1         1      2
# 1          1          3     Afghanistan    AFG         0      2
# 2          1          3          Angola    AGO         0      2
# 3          1          6  United Kingdom    GB1         1      2
# 4          1          6         Albania    ALB         0      2
#
#                 type        admin adm0_a3  geou_dif  ... region_un  \
# 0            Country        Aruba     ABW         0  ...  Americas
# 1  Sovereign country  Afghanistan     AFG         0  ...      Asia
# 2  Sovereign country       Angola     AGO         0  ...    Africa
# 3         Dependency     Anguilla     AIA         0  ...  Americas
# 4  Sovereign country      Albania     ALB         0  ...    Europe
#
#          subregion                  region_wb name_len long_len  abbrev_len  \
# 0        Caribbean  Latin America & Caribbean        5        5           5
# 1    Southern Asia                 South Asia       11       11           4
# 2    Middle Africa         Sub-Saharan Africa        6        6           4
# 3        Caribbean  Latin America & Caribbean        8        8           4
# 4  Southern Europe      Europe & Central Asia        7        7           4
#
#   tiny homepart     featureclass  \
# 0    4      -99  Admin-0 country
# 1  -99        1  Admin-0 country
# 2  -99        1  Admin-0 country
# 3  -99      -99  Admin-0 country
# 4  -99        1  Admin-0 country
#
#                                             geometry
# 0  POLYGON ((-69.89912109375 12.45200195312499, -...
# 1  POLYGON ((74.89130859375001 37.231640625, 74.8...
# 2  (POLYGON ((14.19082031250008 -5.8759765625, 14...
# 3  POLYGON ((-63.001220703125 18.22177734374999, ...
# 4  POLYGON ((20.06396484375 42.547265625, 20.1035...
#
# [5 rows x 64 columns]

# %%
f, ax = plt.subplots(1)

world.plot(ax=ax, color='grey', edgecolor='black')

gfd.plot(ax=ax, marker='o', color='red', markersize=20)

plt.axis("off")

plt.savefig('./images/EmbaymentsWorld.svg')
plt.savefig('./images/EmbaymentsWorld.png')

# %% [markdown]
# # ***Ward Agglomerative Clustering***
#
#
# Clustering analysis of the embayment measurements should yield morphological archetypes for large coastal features. This analysis will be conducted here using the kmeans module from sklearn.cluster package.First we create a subset of dfclean (because it is a Pandas DataFrame not a Geopandas GeoDataFrame) and store it in the variable ***X***. Then we set up the model options and store them in the variable ***kmeans***. Lastly, we create the model by applying the _KMeans.fit(X)_ method and store it in ***kluster***. ***kluster*** now contains the model and centroids for the cluster analysis that we just performed.
#
# ### Using K-Means
#
# I have modified this notebook to use instead AgglomerativeClustering from sklearn using the Ward method. Kmeans methods have been commented out but are still available to view.

# %%
from sklearn.cluster import KMeans

X = dfclean[dfclean.loc[:,'Lm'].notna() & dfclean.loc[:,'Lb'].notna()]
kmeans = KMeans(n_clusters=7, max_iter=10000)
kluster = kmeans.fit(X.loc[:,["Lm","Lb"]])
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-21-f1b9fa341570> in <module>
# ----> 1 from sklearn.cluster import KMeans
#       2
#       3 X = dfclean[dfclean.loc[:,'Lm'].notna() & dfclean.loc[:,'Lb'].notna()]
#       4 kmeans = KMeans(n_clusters=7, max_iter=10000)
#       5 kluster = kmeans.fit(X.loc[:,["Lm","Lb"]])
#
# ModuleNotFoundError: No module named 'sklearn'

# %% [markdown]
# ### Cluster Centers
#
# The computed cluster centers (we specified 3) are stored in the attribute ***cluster_centers_***. Calling this attribute shows that the centroid coordinates are stored in a numpy array (may be useful to know).

# %%
kluster.cluster_centers_
# Out:
# array([[  3874.29545455,  10925.38636364],
#        [ 50286.41666667,  46907.08333333],
#        [  7187.8125    ,  29617.875     ],
#        [  4365.5       , 102281.5       ],
#        [ 68115.33333333,  91153.        ],
#        [ 25804.17647059,  22507.94117647],
#        [ 13342.83333333,  56895.5       ]])

# %% [markdown]
# ### Determining Cluster Category
#
# Determination of each points 'Cluster' is done by applying the ***predict()*** method for each point in the DataFrame ***X***. Here we store those values in the column ***'Cluster'***.

# %%
X['Cluster'] = kluster.fit_predict(X.loc[:,["Lm","Lb"]])

# %%
X.head()
# Out:
#                 Embayment Alt Name Papers Descriptor           Type 1  \
# 0         Lake Illawarra       NaN    NaN       Lake  Barrier Estuary
# 1           Grays Harbour      NaN    NaN    Harbour  Barrier Estuary
# 2             Willapa Bay      NaN    NaN        Bay  Barrier Estuary
# 3  Columbia River Estuary      NaN    NaN    Estuary  Barrier Estuary
# 4           San Diego Bay      NaN    NaN        Bay  Barrier Estuary
#
#          Type 2    Size   Margin         Region                   Country  \
# 0  COAST. PLAIN  Medium  Passive        Oceania                 Australia
# 1           NaN     NaN  Active   North America  United States of America
# 2           NaN     NaN  Active   North America  United States of America
# 3           Ria     NaN  Active   North America  United States of America
# 4           NaN     NaN  Active   North America  United States of America
#
#    ...       Lb            C Unnamed: 19 L Inset L Lat L Long        Lat  \
# 0  ...   8609.0  0.048089209         NaN     NaN   NaN    NaN -34.522622
# 1  ...  20147.0  0.167766913         NaN     NaN   NaN    NaN  46.935778
# 2  ...  40235.0  0.173580216         NaN     NaN   NaN    NaN  46.568658
# 3  ...  12263.0    0.4291772         NaN     NaN   NaN    NaN  46.215964
# 4  ...  17172.0  0.082809224         NaN     NaN   NaN    NaN  32.675456
#
#          Long                                      geometry  Cluster
# 0  150.838517  POINT (150.8385166666667 -34.52262222222222)        0
# 1 -124.052592  POINT (-124.0525916666667 46.93577777777777)        0
# 2 -123.983200           POINT (-123.9832 46.56865833333334)        2
# 3 -123.843736  POINT (-123.8437361111111 46.21596388888889)        0
# 4 -117.144169  POINT (-117.1441694444445 32.67545555555555)        0
#
# [5 rows x 27 columns]

# %% [markdown]
# ### Graphing
#
# Now we can graphically display the cluster grouping using matplotlib.

# %%
colours={0:'r',1:'b', 2:'g', 3:'black', 4: 'y', 5: 'purple', 6:'orange'}
shapes={'LSE': '*', 
        'Open':'s', 
        'Macrotidal': '^', 
        'Tidal Inlet':'X', 
        'Barrier Estuary':'d', 
        'Ria': 'o', 
        'Coastal Plain': 'p' ,
        'Fjord': '8'}

for cluster, group in X.groupby(['Cluster']): # plotting using a for loop see: https://stackoverflow.com/a/50239647
    plt.scatter(group['Lb'], group['Lm'], c=colours[cluster], alpha=0.8, label=cluster)

x=np.linspace(0, (max(X['Lm']) + 5000), 100)
leg1 = plt.legend(title='Cluster', loc='upper right')
y=x
x2=3*y
plt.plot(x, y, 'black', label='C = 1.0')
plt.plot(x2, y, 'r--', label='C < 0.3')
plt.axis([0, (max(dfclean['Lb'])+5000), 0, (max(dfclean['Lm'])+5000)])
plt.xlabel('Minimum Mouth Width (Lm)')
plt.ylabel('Maximum Body Width (Lb)')
plt.legend()



plt.savefig('./images/Kluster1.svg')  # Saving the image
plt.savefig("./images/Kluster1.png")

plt.show()   # Showing the graph

# USING seaborn
#sns.pairplot(x_vars=["Lm"], y_vars=["Lb"], data=X, hue="Cluster", size=5)
#plt.axis([0, max(dfclean['Lm']), 0, max(dfclean['Lb'])])
#y=x
#y2=3*x
#plt.plot(x, y, 'black', label='C = 1.0')
#plt.plot(x, y2, 'r--', label='C < 0.3')
#plt.xlabel('Minimum Mouth Width (Lm)')
#plt.ylabel('Maximum Body Width (Lb)')
#
#plt.savefig('./images/Kluster1Seaborn.svg')  # Saving the image
#plt.savefig("./images/Kluster1Seaborn.png")

 #using plotnine ============
#X['Cluster'] = X['Cluster'].astype(object)
#p = ggplot(aes(x='Lm', y='Lb'), X)
#p = p + geom_point(aes(fill='Cluster', shape='Type 1'), size = 6)
#p =  p + xlab('Minimum Mouth Width (Lm)') + ylab('Maximum Body Width (Lb)')
#p = p + scale_fill_discrete(name='Cluster') + scale_shape_discrete(name='Coastal Feature Class')
#
#p

# %%
X.loc["Type 1"] = X["Type 1"].str.strip(" ")
X.loc["Cluster"] = X["Cluster"].apply(lambda x: str(x))
histdf = pd.crosstab(X["Type 1"], X["Cluster"] , values=X['Embayment'], aggfunc ='count', dropna=True)
X.to_csv('./DataOutput/ClusteredEmbayments.csv', header=True)
histdf.to_csv('./DataOutput/ClusterCrosstab.csv', header=True, index=True)
histdf

# %% [markdown]
# ### Subsetting Data
#
# As you can see, a large potion of the classified data is a part of cluster 0. This could be due to the distribution of other clusters on the euclidean plane. The next step is to remove the sparse points and re-calculate the clustering model. This should be able to provide more appropriate clustering for the dataset. It may be worthwhile reclassifying the sparse points as 'Massive' coastal features. These are not really the concern of this study but it is useful to know that they form a cluster.
#
# Next we will remove all features with a ***L<sub>m</sub>*** greater than 15000m.

# %%
dfcsub = dfclean[dfclean['Lm'] < 15000]
dfcsub

# %%
dfcsub.describe()

# %% [markdown]
# #### Removed Data
#
# The removed data are:

# %%
dfcremoved = dfclean[dfclean['Lm'] > 15000]
dfcremoved
# Out:
#                   Embayment             Alt Name Papers Descriptor  \
# 16              Yakutat Bay                  NaN    NaN        Bay
# 33          Frith of Thames                  NaN    NaN      Frith
# 37                 New Gulf          Golfo Nuevo    NaN       Gulf
# 47           Shoalwater Bay                  NaN    NaN        Bay
# 48              Broad Sound                  NaN    NaN      Sound
# 49           Cambridge Gulf                  NaN    NaN       Gulf
# 50               King Sound                  NaN    NaN      Sound
# 51             Spencer Gulf                  NaN    NaN       Gulf
# 52       Saint Vincent Gulf                  NaN    NaN       Gulf
# 53           Gulf of Nicoya         Golfo Nicoya    NaN       Gulf
# 56        Gulf of Guayaquil   Golfo de Guayaquil    NaN       Gulf
# 58             Delaware Bay                  NaN    NaN        Bay
# 60            Cleveland Bay                  NaN    NaN        Bay
# 61              Halifax Bay                  NaN    NaN        Bay
# 62   Princess Charlotte Bay                  NaN    NaN        Bay
# 63             Blue Mud Bay                  NaN    NaN        Bay
# 68                Hawke Bay                  NaN    NaN        Bay
# 69              Pegasus Bay                  NaN    NaN        Bay
# 70             Tewaenae Bay                  NaN    NaN        Bay
# 71             Monterey Bay                  NaN    NaN        Bay
# 72               Estero Bay                  NaN    NaN        Bay
# 73         Santa Monica Bay                  NaN    NaN        Bay
# 74            San Pedro Bay                  NaN    NaN        Bay
# 76             Banderas Bay     Bahia de Baderas    NaN        Bay
# 77          Gulf of Fonseca     Golfo de Fonseca    NaN       Gulf
# 78              Sechura Bay                  NaN    NaN        Bay
# 79           Mejillones Bay     Bahia Mejillones    NaN        Bay
# 80               Moreno Bay         Bahia Moreno    NaN        Bay
# 81           Gulf of Arauco      Golfo de Arauco    NaN       Gulf
# 82       Bay of Ilha Grande  Baia da Ilha Grande    NaN        Bay
# 83          Bay of Amatique     Bahí de Amatique    NaN        Bay
# 99           Gulf of Tumaco      Golfo de Tumaco    NaN       Gulf
# 132               Shark Bay                  NaN    NaN        Bay
# 133            Exmouth Gulf                  NaN    NaN       Gulf
# 135             Golden Bay                   NaN    NaN        Bay
# 136              Tasman Bay                  NaN    NaN        Bay
# 139           Bay of Marajó       Baía de Marajó    NaN        Bay
# 140         Chiriqui Lagoon                  NaN    NaN     Lagoon
#
#           Type 1           Type 2     Size   Margin           Region  \
# 16         Fjord       Macrotidal      NaN  Active     North America
# 33           LSE             Open    Large  Active          Oceania
# 37           LSE              NaN      NaN  Passive    South America
# 47    Macrotidal          Estuary    Large  Passive          Oceania
# 48    Macrotidal          Estuary    Large  Passive          Oceania
# 49    Macrotidal            Inlet    Large  Passive          Oceania
# 50    Macrotidal              LSE    Large  Passive          Oceania
# 51    Macrotidal              NaN    Large  Passive          Oceania
# 52    Macrotidal              NaN    Large  Passive          Oceania
# 53    Macrotidal              NaN      NaN  Active   Central America
# 56    Macrotidal      Tidal Inlet      NaN   Active    South America
# 58    Macrotidal              NaN      NaN  Passive    North America
# 60          Open              NaN    Large  Passive          Oceania
# 61          Open              NaN  Massive  Passive          Oceania
# 62          Open              NaN  Massive  Passive          Oceania
# 63          Open              LSE    Large  Passive          Oceania
# 68          Open              NaN  Massive  Active          Oceania
# 69          Open              NaN  Massive  Active          Oceania
# 70          Open              NaN  Massive  Active           Oceania
# 71          Open              NaN      NaN  Active     North America
# 72          Open              NaN      NaN  Active     North America
# 73          Open              NaN      NaN  Active     North America
# 74          Open              NaN      NaN  Active     North America
# 76          Open              NaN      NaN  Active     North America
# 77          Open      Tidal Inlet      NaN  Active   Central America
# 78          Open              NaN      NaN   Active    South America
# 79          Open              NaN      NaN   Active    South America
# 80          Open              NaN      NaN   Active    South America
# 81          Open              NaN      NaN   Active    South America
# 82          Open              NaN      NaN  Passive    South America
# 83          Open  Barrier Estuary      NaN   Active  Central America
# 99   Tidal Inlet              NaN      NaN   Active    South America
# 132          NaN              NaN    Large  Passive          Oceania
# 133          NaN              NaN    Large  Passive          Oceania
# 135          NaN              NaN    Large  Active          Oceania
# 136          NaN              NaN    Large  Active          Oceania
# 139          NaN              NaN      NaN  Passive    South America
# 140          NaN              NaN      NaN   Active  Central America
#
#                       Country  ...       Lm       Lb            C Unnamed: 19  \
# 16   United States of America  ...  28042.0  26862.0  1.043928226         NaN
# 33                New Zealand  ...  16516.0  21660.0  0.762511542         NaN
# 37                  Argentina  ...  16370.0  67664.0  0.241930716         NaN
# 47                  Australia  ...  27876.0  14032.0  1.986602052         NaN
# 48                  Australia  ...  28104.0  10771.0  2.609228484         NaN
# 49                  Australia  ...  18212.0  21209.0  0.858692065         NaN
# 50                  Australia  ...  38397.0  56835.0  0.675587226         NaN
# 51                  Australia  ...  80096.0  85736.0  0.934216665         NaN
# 52                  Australia  ...  58870.0  56996.0    1.0328795         NaN
# 53                 Costa Rica  ...  30602.0  18906.0  1.618639585         NaN
# 56                    Ecuador  ...  31957.0  26263.0  1.216806915         NaN
# 58   United States of America  ...  18734.0  47147.0   0.39735296         NaN
# 60                  Australia  ...  24983.0  21382.0  1.168412684         NaN
# 61                  Australia  ...  75243.0  52692.0  1.427977682         NaN
# 62                  Australia  ...  50283.0  48317.0  1.040689612         NaN
# 63                  Australia  ...  45938.0  89765.0   0.51175848         NaN
# 68                New Zealand  ...  78312.0  97958.0   0.79944466         NaN
# 69                New Zealand  ...  65163.0  57563.0  1.132029255         NaN
# 70                New Zealand  ...  26762.0  30936.0  0.865076287         NaN
# 71   United States of America  ...  35177.0  42076.0  0.836034794         NaN
# 72   United States of America  ...  18248.0  15595.0  1.170118628         NaN
# 73   United States of America  ...  43216.0  43232.0  0.999629904         NaN
# 74   United States of America  ...  25742.0  18590.0  1.384722969         NaN
# 76                     Mexico  ...  29266.0  27785.0  1.053302141         NaN
# 77                   Honduras  ...  32011.0  71729.0  0.446276959         NaN
# 78                       Peru  ...  51831.0  48446.0   1.06987161         NaN
# 79                      Chile  ...  16346.0  13495.0  1.211263431         NaN
# 80                      Chile  ...  19614.0  18783.0  1.044242134         NaN
# 81                      Chile  ...  38122.0  40801.0  0.934339845         NaN
# 82                     Brazil  ...  22762.0  23850.0  0.954381551         NaN
# 83                     Belize  ...  23507.0  45100.0  0.521219512         NaN
# 99                   Colombia  ...  19813.0  24194.0  0.818922047         NaN
# 132                 Australia  ...  39962.0  47989.0  0.832732501         NaN
# 133                 Australia  ...  47413.0  38438.0  1.233492898         NaN
# 135               New Zealand  ...  34481.0  34214.0  1.007803823         NaN
# 136               New Zealand  ...  35691.0  27603.0  1.293011629         NaN
# 139                    Brazil  ...  59760.0  29500.0  2.025762712         NaN
# 140                    Panama  ...  17635.0  58136.0  0.303340443         NaN
#
#      L Inset L Lat  L Long        Lat        Long  \
# 16       NaN   NaN     NaN  59.692914 -139.862217
# 33       NaN   NaN     NaN -37.118200  175.417519
# 37       NaN   NaN     NaN -42.720947  -64.527094
# 47       NaN   NaN     NaN -22.438886  150.447308
# 48       NaN   NaN     NaN -22.364492  149.861222
# 49       NaN   NaN     NaN -14.867636  128.244394
# 50       NaN   NaN     NaN -16.839914  123.512297
# 51       NaN   NaN     NaN -34.318714  137.018436
# 52       NaN   NaN     NaN -35.042800  138.073128
# 53       NaN   NaN     NaN   9.887675  -84.823267
# 56       NaN   NaN     NaN  -3.016939  -80.021481
# 58       NaN   NaN     NaN  39.061839  -75.184150
# 60       NaN   NaN     NaN -19.225858  146.883497
# 61       NaN   NaN     NaN -18.945272  146.478714
# 62       NaN   NaN     NaN -14.318414  143.960083
# 63       NaN   NaN     NaN -13.419578  136.093606
# 68       NaN   NaN     NaN -39.311186  177.325356
# 69       NaN   NaN     NaN -43.343011  172.867839
# 70       NaN   NaN     NaN -46.230806  167.533375
# 71       NaN   NaN     NaN  36.750036 -121.903406
# 72       NaN   NaN     NaN  35.378417 -120.886739
# 73       NaN   NaN     NaN  33.921894 -118.572944
# 74       NaN   NaN     NaN  33.707661 -118.147969
# 76       NaN   NaN     NaN  20.615111 -105.415219
# 77       NaN   NaN     NaN  13.144956  -87.649775
# 78       NaN   NaN     NaN  -5.625339  -80.999672
# 79       NaN   NaN     NaN -23.046903  -70.436111
# 80       NaN   NaN     NaN -23.561550  -70.470378
# 81       NaN   NaN     NaN -37.132556  -73.318197
# 82       NaN   NaN     NaN -23.157844  -44.566253
# 83       NaN   NaN     NaN  15.970131  -88.705850
# 99   25159.0   NaN     NaN   1.875469  -78.638600
# 132      NaN   NaN     NaN -25.972672  114.004172
# 133      NaN   NaN     NaN -22.163247  114.286922
# 135      NaN   NaN     NaN -40.715906  172.835178
# 136      NaN   NaN     NaN -41.150264  173.174717
# 139      NaN   NaN     NaN  -0.665889  -48.320147
# 140      NaN   NaN     NaN   9.056731  -82.073383
#
#                                            geometry
# 16     POINT (-139.8622166666667 59.69291388888889)
# 33               POINT (175.4175194444444 -37.1182)
# 37    POINT (-64.52709444444444 -42.72094722222222)
# 47     POINT (150.4473083333333 -22.43888611111111)
# 48     POINT (149.8612222222222 -22.36449166666667)
# 49     POINT (128.2443944444444 -14.86763611111111)
# 50     POINT (123.5122972222222 -16.83991388888889)
# 51     POINT (137.0184361111111 -34.31871388888889)
# 52               POINT (138.0731277777778 -35.0428)
# 53              POINT (-84.82326666666667 9.887675)
# 56    POINT (-80.02148055555556 -3.016938888888889)
# 58              POINT (-75.18415 39.06183888888889)
# 60     POINT (146.8834972222222 -19.22585833333333)
# 61     POINT (146.4787138888889 -18.94527222222222)
# 62     POINT (143.9600833333333 -14.31841388888889)
# 63     POINT (136.0936055555556 -13.41957777777778)
# 68     POINT (177.3253555555555 -39.31118611111111)
# 69     POINT (172.8678388888889 -43.34301111111111)
# 70            POINT (167.533375 -46.23080555555556)
# 71     POINT (-121.9034055555556 36.75003611111111)
# 72     POINT (-120.8867388888889 35.37841666666667)
# 73     POINT (-118.5729444444444 33.92189444444444)
# 74     POINT (-118.1479694444445 33.70766111111111)
# 76     POINT (-105.4152194444444 20.61511111111111)
# 77     POINT (-87.64977500000001 13.14495555555555)
# 78     POINT (-80.99967222222222 -5.62533888888889)
# 79    POINT (-70.43611111111112 -23.04690277777778)
# 80             POINT (-70.47037777777778 -23.56155)
# 81    POINT (-73.31819722222222 -37.13255555555556)
# 82    POINT (-44.56625277777778 -23.15784444444444)
# 83              POINT (-88.70585 15.97013055555556)
# 99     POINT (-78.63860000000001 1.875469444444444)
# 132    POINT (114.0041722222222 -25.97267222222222)
# 133    POINT (114.2869222222222 -22.16324722222222)
# 135    POINT (172.8351777777778 -40.71590555555556)
# 136    POINT (173.1747166666667 -41.15026388888889)
# 139  POINT (-48.32014722222223 -0.6658888888888889)
# 140    POINT (-82.07338333333333 9.056730555555557)
#
# [38 rows x 26 columns]

# %%
dfcremoved['Margin'] = dfcremoved["Margin"].apply(lambda x: x.strip())
dfcrgroup = dfcremoved.groupby(["Type 1", 'Margin']).count()
# Out:
# C:\Users\mpbaum\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
dfcrgroup['Embayment']
# Out:
# Type 1       Margin
# Fjord        Active      1
# LSE          Active      1
#              Passive     1
# Macrotidal   Active      2
#              Passive     7
# Open         Active     14
#              Passive     5
# Tidal Inlet  Active      1
# Name: Embayment, dtype: int64

# %% [markdown]
# As you can see the majority of embayments removed during this process were classified as Macrotidal and Open embayments. If we conduct the same measurement on the <15000 dataset we get:

# %%
dfcsgroup = pd.crosstab(dfcsub['Type 1'], dfcsub['Margin'], values=dfcsub['Embayment'], aggfunc='count')
dfcsgroup
# Out:
# Margin           Active  Active   Passive  Passive
# Type 1
# Barrier Estuary     2.0      6.0      5.0       NaN
# Coastal Plain       NaN      1.0      NaN       NaN
# Fjord               1.0      NaN      NaN       NaN
# LSE                11.0      3.0     10.0       1.0
# Macrotidal          NaN      2.0      1.0       1.0
# Open                NaN      4.0      3.0       NaN
# Ria                 NaN      2.0      4.0       NaN
# Tidal Inlet         2.0      4.0      2.0       NaN

# %% [markdown]
# ## Second K-means
#
# Now we can conduct a second K-means on the subsetted group.

# %%
X_2 = dfcsub
kmeans_2 = KMeans(n_clusters=7, max_iter=10000)
kluster_2 = kmeans_2.fit(X_2.loc[:, ['Lm','Lb']])

# %%
kluster_2.cluster_centers_
# Out:
# array([[  2626.125     ,  19106.6875    ],
#        [  7012.        ,  73973.33333333],
#        [  6501.8       ,  50972.2       ],
#        [  7043.        , 120752.        ],
#        [  2438.51851852,   7546.22222222],
#        [  7529.57142857,  35664.        ],
#        [ 12062.55555556,  20222.77777778]])

# %%
X_2['Cluster'] = kluster_2.predict(X_2.loc[:,['Lm','Lb']]) #kluster_2.fit(X_2.loc[:,['Lm','Lb']])
# Out:
# C:\Users\mpbaum\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
colours={0:'r',1:'b', 2:'g', 3:'black', 4: 'y', 5: 'purple', 6:'orange'}

plt.scatter(x=X_2['Lm'], y=X_2['Lb'], c=X_2['Cluster'].apply(lambda x: colours[x]))
x=np.linspace(0, max(X_2['Lb']), 100)
y=x
y2=3*x
plt.plot(x, y, 'r--')
plt.plot(x, y2, 'g--')
plt.axis([0, max(X_2['Lm']), 0, max(X_2['Lb'])])
plt.xlabel('Minimum Mouth Width (Lm)')
plt.ylabel('Maximum Body Width (Lb)')

plt.savefig('./images/Kluster2_Subset.svg')  #saving images
plt.savefig('./images/Kluster2_Subset.png')  #saving images

plt.show()

# %% [markdown]
# This is a preliminary cluster model and more data is required for a more robust clustering method. However lets look at the Cluster counts by Type 1

# %%
fin = pd.crosstab(X_2["Type 1"], X_2["Cluster"], values=X_2['Embayment'], aggfunc='count')
fin
# Out:
# Cluster            0    1    2    3    4    5    6
# Type 1
# Barrier Estuary  4.0  1.0  1.0  NaN  3.0  4.0  NaN
# Coastal Plain    NaN  NaN  NaN  NaN  NaN  NaN  1.0
# Fjord            NaN  NaN  NaN  NaN  NaN  1.0  NaN
# LSE              9.0  2.0  3.0  1.0  9.0  2.0  1.0
# Macrotidal       NaN  NaN  NaN  NaN  NaN  NaN  4.0
# Open             NaN  NaN  1.0  NaN  4.0  NaN  2.0
# Ria              2.0  NaN  NaN  NaN  3.0  NaN  1.0
# Tidal Inlet      1.0  NaN  NaN  NaN  7.0  NaN  NaN

# %% [markdown]
# # Note
# Second K-Means is worse, use single K-means and then conduct Chi-Squared. This is done in another notebook PLEASE CONSOLIDATE.
